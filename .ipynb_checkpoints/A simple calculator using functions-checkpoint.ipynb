# %% [markdown]
# ## A simple calculator using functions
#
# 1) Read code and discuss - ask questions!
#
# 2) Comment code
#
# 3) Extend the calculator with 5 more functions

# %%
def mainMenu():  #Main menu where user decides what to do is defined here
    validChoices = ["A", "S", "D", "E", "M", "R", "C", "P", "F"]  #the valid choices which the user can make are defined
    valid = False
    while not valid:
        print("A)dd numbers")  #the maths operations which the user can perform by typing the Letter in brackets are here
        print("S)ubtract numbers")
        print("D)ivide numbers")
        print("E)xponentiate a number to the power of another")
        print("M)ultiply") 
        print("R)oot")
        print("C)ube Root")
        print("P)i multiply")
        print("F)Euler constant multiply")
        
        choice = input("choose your operation:").upper()
        if choice not in validChoices: #if the user's choice is not defined in the parameters of the validChoices variable then the print message will be displayed 
            print(" ")
            print(" ")
            print("That is not a valid choice :(")
            print(" ")
            print("Try again")
        else:
            valid= True
            
    return choice
    

def enterNumber(): #the user's answer is defined as a function
    valid = False
    while not valid:
        try:
            x=int(input("enter your first number: ")) #the first input of the user is defined as 'limited' to an integer
            valid=True
        except ValueError: #if something other than a number is entered there will be a error message printed
            print("That was not a valid number.. please try again")
    
    return x #the output of the two numbers the user has entered is outputted

def add(x,y): #the addition function is defined
    
    return x+y

def subtract(x,y): #the subtract function is defined 
    
    return x-y #how the function will be executed is defined 

def divide(x,y): #the divide function is defined 
    return x/y #how the function will be executed is defined

def exponent(x,y): #the exponent function is defined 
    return x**y #how the function will be executed is defined

def multiply(x,y): #the multiply function is defined
    return x*y #how the function will be executed is defined

def root(x): #the square root function is defined
    return x**0.5 #how the function will be executed 

def cubeRoot(x): #the cube root function is defined
    return x ** 0.33333333333333333333 #how the function will be executed

def Pi(x): #the pi function is defined
    return x * 3.14159 #how the function will be executed

def eulerConstant(x): #the sine function is defined
    return x * 0.5772156649

#main program starts here
again = "y"
while again == "y":
    
    userChoice = mainMenu()
    if userChoice == "A": #if the user chooses A for addition this is the process that takes place to display it
        answer = add(enterNumber(), enterNumber())
    elif userChoice == "S": #if the user chooses S for subtract this is the process that takes place to display it
        answer = subtract(enterNumber(), enterNumber())
    elif userChoice == "D": #if the user chooses D for division this is the process that takes place to display it
        answer = divide(enterNumber(), enterNumber())
    elif userChoice == "E": 
        answer = exponent(enterNumber(), enterNumber())
    elif userChoice == "M":
        answer = multiply(enterNumber(), enterNumber ())
    elif userChoice == "R":
        answer = root(enterNumber())
    elif userChoice == "C":
        answer = cubeRoot(enterNumber())
    elif userChoice == "P":
        answer = Pi(enterNumber())
    elif userChoice == "F":
        answer = eulerConstant(enterNumber())
    else:
        print("error - we should never get here") #if the user chooses something other than the options A,S or D an error is displayed
    
    print(" ")
    print("the answer from your calcaulation is="+str(answer))
    print(" ")
    print("Input a new question:")
# Out:
# A)dd numbers
# S)ubtract numbers
# D)ivide numbers
# E)xponentiate a number to the power of another
# M)ultiply
# R)oot
# C)ube Root
# P)i multiply
# F)Euler constant multiply
# choose your operation:F
# enter your first number: 5
#
# the answer from your calcaulation is=2.8860783244999997
#
# Input a new question:
# A)dd numbers
# S)ubtract numbers
# D)ivide numbers
# E)xponentiate a number to the power of another
# M)ultiply
# R)oot
# C)ube Root
# P)i multiply
# F)Euler constant multiply
